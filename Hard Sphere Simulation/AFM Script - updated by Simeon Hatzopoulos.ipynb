# %% [markdown]
# # AFM Simulation Code
#
# Authors: Brendan McKiernan, Simeon Hatzopoulos
#
# Date: 14.06.2021

# %%
import sys
#!{sys.executable} -m pip install py3Dmol

# Libraries needed to install to run this module (not in standard anaconda):
#conda install -c anaconda biopython
#conda install py3dmol -c conda-forge
#conda install nglview -c conda-forge

# %% [markdown]
# Importing / installing packages
# The basic ideas in 2d
# How to use it
# Flow chart with each of the function and how they interact - overview of script
# Understanding how each function works
# Moving on / next steps

# %%
# Importing relevant modules
# %matplotlib notebook
import numpy as np     
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image # For displaying images in Markdown
import pandas as pd #### might need to use this later
from mpl_toolkits.mplot3d import axes3d
import nglview as nv
import py3Dmol
from Bio.PDB import * #### From video: youtube.com/watch?v=mL8NPpRxgJA&ab_channel=CarlosG.Oliver
import os
import tkinter as tk
from tkinter import *

#### PDB stuff:
pdbl = PDBList()
parser = MMCIFParser()
from Bio.PDB.PDBParser import PDBParser
pdb_parser = PDBParser(PERMISSIVE=1)
from Bio.PDB import Entity
from numpy import random

# %%
def com_function(structure):
    
    ''' This function finds the centre of mass of each atom in the protein 
    The only input is structure, which is the PDB file.
    It returns the '''
    
    
    atom_list = structure.get_atoms() # Return atoms from residue, all atoms are unpacked.

    masses_array = []   #array of all atom masses  *empty*
    positions_array = [ [], [], [] ] #array of all positions  *empty*
    atom_pos_array = [ [], [], [] ]   #array of all atom positions  *empty*  pos: [x], [y], [z]
    
    for atom in atom_list:
        masses_array.append(atom.mass)  #creates array of all atoms masses in atom_list
        
        for i, coord in enumerate(atom.coord.tolist()):  #lists the atom coordinates and designates them a count i
            positions_array[i].append(coord) #creates an array of atom coordinates 
    
    #designating a mass to a position all three directions must be accounted for 
    for atom_index, atom_mass in enumerate(masses_array):
        atom_pos_array[0].append(positions_array[0][atom_index]*atom_mass) #x coordinates 
        atom_pos_array[1].append(positions_array[1][atom_index]*atom_mass) #y coordinates
        atom_pos_array[2].append(positions_array[2][atom_index]*atom_mass) #z coordinates
        
    return [sum(coord_list)/sum(masses_array) for coord_list in atom_pos_array]

# %% [markdown]
# Data is binned to allow for AFM scanning:

# %%
def bin_and_label_creater(min,max,step):
    
    '''Creating bins of a certain width and their respective labels. Inputs: 
    min - minumum value (start of sample) 
    max - maximum value (end of sample)
    step - width of the bins'''
    
    delta = step #(max-min)*(1/pixels) 
    
    #creating bins between min and max in delta steps 
    bins = np.arange(min,max+delta,delta)
    
    #creating labels in the middle of each bin
    labels = np.arange(min+(delta/2),max+(delta/2),delta)

    return(bins,labels)

# %%
#### Let's create a 3D tip now

def threedeetipheightcalc(x,y,tip_central_x,tip_central_y,theta_in_degrees,r):
    
    '''Calculates and returns the value of height of the tip. The inputs are:
    x - a given value for x (at which the height is to be found)
    y - a given value for y (at which the height is to be found)
    tip_central_x - tip centre x position
    tip_central_y - tip cetnre y position
    theta_in_degree, r - Tip's dimensions (r is spehre radius)'''
    
    # converting theta from degrees to radians 
    theta = theta_in_degrees*(np.pi/180)
   
    # finding the gradient based on figure 6 in report 
    alpha = 1/(np.tan(theta))   # alpha is the gradient (or m)

    # creating the parameter delta in figure 6 - the distance between tip and tangent point 
    grad_del = np.sqrt(abs((r*alpha)**2/(1+alpha**2)))
    
    # the tangent point (cone meets sphere)
    X = tip_central_x + grad_del
    y_int = -np.sqrt(r**2 - grad_del**2) + r - alpha*(grad_del) #finding the y intercept - see report 
    dist_from_centre = ((x-tip_central_x)**2 + (y - tip_central_y)**2) # distance from the centre of tip
    
    z0 = y_int # should always be equal
    
    #Constructing the conical and spherical parts 
    if dist_from_centre < grad_del**2: #this would be within delta and therefore the spherical part  
        z = -np.sqrt(r**2 -(x-tip_central_x)**2 - (y-tip_central_y)**2) + r
        
    else: #else we are beyond delta at the conical part 
        c = np.tan(theta) # not equal to 1/tan(theta) bc theta is defined as angle between vertical not horizontal
        z = np.sqrt((((x-tip_central_x)**2 + (y-tip_central_y)**2)/(c**2))) + z0 
    
    return(z) #returns the height of tip


def threedeetipcreater(X,Y,tip_central_x,tip_central_y,theta_in_degrees,r):
    
    '''This function creates an array representing the height of the tip across all X and Y. Inputs:
    X - x range along which the array runs
    Y - y range along which the array runs
    tip_central_x - tip centre x position
    tip_central_y - tip cetnre y position
    theta_in_degree, r - Tip's dimensions (r is spehre radius)'''
    
    # creating an array of all heights Z
    Z= []  
    
    # For each y value a whole array off x values is created. When accumulating all y values a grid is created
    for n in range(len(Y)):  
        Z_sub_array=[]
        for i in range(len(X)): # An array of x values for each single y value
            Z_sub_array_element = threedeetipheightcalc(X[i],Y[n],tip_central_x,tip_central_y,theta_in_degrees,r)
            Z_sub_array.append(Z_sub_array_element)
        Z.append(Z_sub_array) # create an array with height at certain x and y coordinates
    Z_array = np.array(Z) 
    
    return(Z_array) #return all heights across X by Y grid

# %%
### Illustrating the tip
fig = plt.figure()
ax = fig.add_subplot(projection='3d')  #prev:   fig.add_subplot(111, projection='3d')

i = 20
x = np.arange(-i,i,1)
y = np.arange(-i,i,1)

X, Y = np.meshgrid(x, y)
Z = threedeetipcreater(x,y,0,0,12,8)
ax.plot_surface(X,Y,Z, rstride = 1, cstride = 1)

#chaning axes proportion to depict an accurate tip
s = 30
ax.auto_scale_xyz([-s, s], [-s, s], [0, 50])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def df_from_structure(structure,x_rot,y_rot,z_rot,view_style):
    
    
    t0 = time.time()
    
    '''This function  produces a dataframe with the XYZ coordinates of each
    atom and automatically adjust the Z values so the minimum Z value equals zero. Inputs:
    structue of the PDB file 
    The user's x-axis, y-axis and z-axis rotation angles 
    The view style...'''
    
    
    # Creating rotation matrices according to user input 
    null_rotation_matrix = rotaxis2m(0, Vector(0,0,1))  #BioPython command to rotate around axis m
    rotation_matrix = rotaxis2m(x_rot*(np.pi/180), Vector(1,0,0)) # convert to radians 
    rotation_matrix_2 = rotaxis2m(z_rot*(np.pi/180), Vector(0,0,1))
    rotation_matrix_3 = rotaxis2m(y_rot*(np.pi/180), Vector(0,1,0))
    
    if len(structure) == 1: 
        #retrieving atoms, the centre of mass and its position
        atoms = structure.get_atoms() #BioPython: structure.get --> position of atoms
        com = com_function(structure) #finding the centre of mass using previous function
        mean_x, mean_y, mean_z = com[0],com[1],com[2] #poistion of centre of mass

        ###### Not quite sure ######
        translation_matrix = np.array((0, 0, 0), 'f')
        true_translation_matrix = np.array((-mean_x, -mean_y, -mean_z), 'f')  

        #creating coordinate arrays 
        x_coord_array=[]
        y_coord_array=[]
        z_coord_array=[]

        #Transforming the protein to the user's preferred starting orientation
        for atom in atoms:
            atom.transform(null_rotation_matrix, true_translation_matrix)  #applies the matrices to each atom 
            atom.transform(rotation_matrix,translation_matrix) 
            atom.transform(rotation_matrix_2, translation_matrix)
            atom.transform(rotation_matrix_3, translation_matrix)

            x = atom.get_coord()[0]  #Returns atomic coordinates for x
            y = atom.get_coord()[1]  #Returns atomic coordinates for y
            z = atom.get_coord()[2]  #Returns atomic coordinates for z

            # New set of coordnates for User's orientation
            x_coord_array.append(-x) 
            y_coord_array.append(-y)
            z_coord_array.append(-z)

        # Transposing the tip (either up or down) accoring to the minium displacement - see report 
        z_min = np.min(z_coord_array) #finding minimum displacement between tip and sample
        z_adjust_array = (-z_min)*np.ones(len(z_coord_array)) #creates an array with only -z terms 
        final_z_coord_array = np.add(z_coord_array,z_adjust_array) #this array is subtracted from z to shift the tip down

        sample_height_max = np.max(final_z_coord_array) #why max?

        # Creating a dataframe for x y and z coordinates (in one set)
        d = {'X': x_coord_array, 'Y': y_coord_array, 'Z': final_z_coord_array} 
        df = pd.DataFrame(data=d) # produces correct data frame

        #viewing the protein
        post_adj_view = nv.show_biopython(structure)
        post_adj_view.add_representation(view_style, selection='protein')

        ### Returning Structure to original rotation (if confused query me via email: brendan.mckiernan.17@ucl.ac.uk)
        atoms = structure.get_atoms()
        com = com_function(structure)
        mean_x, mean_y, mean_z = com[0],com[1],com[2]

        #resets the protein to its orignal position: Now user can enter a different orientation
        null_rotation_matrix = rotaxis2m(0, Vector(0,0,1))
        rotation_matrix = rotaxis2m(-x_rot*(np.pi/180), Vector(1,0,0)) #opposite to matrices above
        rotation_matrix_2 = rotaxis2m(-z_rot*(np.pi/180), Vector(0,0,1)) #resets previous rotations
        rotation_matrix_3 = rotaxis2m(-y_rot*(np.pi/180), Vector(0,1,0))
        translation_matrix = np.array((0, 0, 0), 'f')
        true_translation_matrix = np.array((-mean_x, -mean_y, -mean_z), 'f')  

        for atom in atoms:
            atom.transform(rotation_matrix_3,translation_matrix)
            atom.transform(rotation_matrix_2, translation_matrix)
            atom.transform(rotation_matrix, translation_matrix)
        

    elif type(structure1) is tuple:
    #user must input x, y and z coordinate arrays  
        #unpacking array
        x1 = structure1[0]
        y1 = structure1[1]
        z1 = structure1[2]
        
        #flattening 
        x_flat = x1.flatten()
        y_flat = y1.flatten()
        z_flat = z1.flatten()

         # Transposing the tip (either up or down) accoring to the minium displacement - see report 
        z_min = np.min(z_flat) #finding minimum displacement between tip and sample
        z_adjust_array = (-z_min)*np.ones(len(z_flat)) #creates an array with only -z terms 
        final_z_flat = np.add(z_flat,z_adjust_array) #this array is subtracted from z to shift the tip down

        sample_height_max = np.max(final_z_flat) #why max?
                                   
        d = {'X': x_flat, 'Y': y_flat, 'Z': final_z_flat} 
        df = pd.DataFrame(data=d) # produces correct data frame
        
        post_adj_view = 0 
        #post_adj_view = ax.plot_surface(x1, y1, z1, cmap=plt.cm.YlGnBu_r)
        #post_adj_view.add_representation(view_style, selection='protein')
        
        #print(df)
        
    else:
        
        #Data1 = pd.read_csv('Data_array.csv', index_col=False)
        
        x1, y1, z1 = structure1.T.values
        
        #flattening 
        x_flat = x1.flatten()
        y_flat = y1.flatten()
        z_flat = z1.flatten()

         # Transposing the tip (either up or down) accoring to the minium displacement - see report 
        z_min = np.min(z_flat) #finding minimum displacement between tip and sample
        z_adjust_array = (-z_min)*np.ones(len(z_flat)) #creates an array with only -z terms 
        final_z_flat = np.add(z_flat,z_adjust_array) #this array is subtracted from z to shift the tip down

        sample_height_max = np.max(final_z_flat) #why max?
                                   
        d = {'X': x_flat, 'Y': y_flat, 'Z': final_z_flat} 
        df = pd.DataFrame(data=d) # produces correct data frame
        
        post_adj_view = 0
        #post_adj_view = ax.plot_surface(x1, y1, final_z_flat, cmap=plt.cm.YlGnBu_r)
        #post_adj_view.add_representation(view_style, selection='protein')
        
    t1 = time.time()
    #t_dffstr = t1- t0
    print("df_from_structure", t1 - t0)
    
    return(df, sample_height_max, post_adj_view) #returns data frame, max height and views the protein

# %%
##### Making a function for taking structure, zeroing and putting into a binned dataframe:

    

def structure_data_extracter(structure,xstep,ystep,extension,x_rot,y_rot,z_rot,view_style):
    
    t0 = time.time()
    
    '''This function takes the structure and cuts it into bins. Inputs are:
    structue of the PDB file 
    xstep and ystep - of the bins
    extension - size of the stage on which the protein sits
    The user's x-axis, y-axis and z-axis rotation angles 
    The view style...'''
    
    #Using the previous function to create the dataframe we wish to work with (including orientation)
    #take structure and zero, put into dataframe
    new_df, sample_height_max, post_adj_view = df_from_structure(structure,x_rot,y_rot,z_rot,view_style) 
    
    # finding the maximums and minimums for x and y in this data frame
    Y_max, Y_min = new_df['Y'].max(), new_df['Y'].min() #function extracting max and min 
    X_max, X_min = new_df['X'].max(), new_df['X'].min()
    
    # creating the bins (and labels) using the bin and label creator function 
    Xbins,Xlabels= bin_and_label_creater(X_min-extension,X_max+extension,xstep)
    Ybins,Ylabels= bin_and_label_creater(Y_min-extension,Y_max+extension,ystep)
    
    #pd.cut takes a continuous data set and cuts and sorts it into bins:
    new_df['Binned_Y'] = pd.cut(new_df['Y'], Ybins, right = False, labels = Ylabels) 
    new_df['Binned_X'] = pd.cut(new_df['X'], Xbins, right = False, labels = Xlabels)
    
    sorted_bdf = new_df.sort_values('Binned_X') #sorting the bins for X

    #zeroing the data and dropping values that are not needed - only height is important 
    reduced_col_bdf = sorted_bdf.drop(columns = ['X','Y']) #dropping X and Y - no longer needed 
    reduced_sorted_bdf = reduced_col_bdf.groupby(['Binned_X','Binned_Y'])['Z'].max() #taking the max z values 
    reduced_sorted_bdf_filled = reduced_sorted_bdf.replace(np.nan, 0.0) #nan - 'not a number' replaced with 0
    
    t1 = time.time()
    print(t1-t0)
    
    return(reduced_sorted_bdf_filled,Xlabels,Ylabels,new_df,sample_height_max,post_adj_view)

# %%
##### creating a 3D Tip Height Calculator:

def height_diff_calc_three_dee(Xlabels,Ylabels,reduced_sorted_bdf_filled,tip_central_x,tip_central_y,theta_in_degrees,r):
    
    '''This function calculates the adjustment to the height of the tip, based on the tip's steric
    interaction with the structure. Inputs are: 
    Xlables, Ylables - created by the `structure_data_extracter`
    reduced_sorted_bdf_filled - the binned date frame
    the tip position and dimenstion (theta and r)'''
      
    #Again a grid of values for Y and X is created, this time for the binned data
    
    Z= []
    for n in range(len(Ylabels)): #array for Ylabels 
        Z_sub_array=[]  
        for i in range(len(Xlabels)):  
            Z_sub_array_element = reduced_sorted_bdf_filled[i*len(Ylabels)+n] #array of Xlables for each Ylabel  
            Z_sub_array.append(Z_sub_array_element)  
        Z.append(Z_sub_array)  
    Z_array = np.array(Z) #creating an array for heights Z in binned data   
    
    #Z_array = np.meshgrid(Ylabels, reduced_sorted_bdf_filled, copy=True, sparse=False, indexing='xy')
       
    #creating a tip for this particular binned data frame 
    Z_tip = threedeetipcreater(Xlabels,Ylabels,tip_central_x,tip_central_y,theta_in_degrees,r)
    
    #Finding the displacement of the tip and correcting it - AFM measuring 
    height_delta = Z_tip - Z_array #difference between data and tip
    min_delta = np.min(height_delta) #finding miminum distance 
    corrected_height_delta = (-1)*min_delta #subtracting the minimum difference 
    
    return(corrected_height_delta) #returns the new height of tip

# %%
def error_signal(x,setpoint,arb,n,grad): #what is arb?
    
    '''Calculates the error signal for the feedback mechanics based on the 
    difference between the setpoint height and the hight of probe. Inputs:
    x - position 
    setpoint - the height at wich the tip begins 
    arb - arbitrary number after which the feedback mechanism doesn't increase 
    grad - gradient of error graph (see report)'''
    
    # creating a linear error graph up to a point where the error stays constant (no effect on tip)
    if x > (setpoint+arb):
        error_value = -grad*(arb)  #linear relationship when z is below the setpoint 
        
    else :
        error_value = -grad*(x-setpoint) #no effect (horizontal line) when z is above the setpoint 
             
    return(error_value)  #returns the value at a certain position x


### Now the feedback must be calculated 
def feedback2d(scanline,setpoint,arb,KP_eff,KI,n,grad):
    
    '''Applies the feedback mechanism to a scanline and calculates the error signal at each point.
    The strength of feedback is based on the values of KP & KI. Inputs:
    scanline - The array of postions coordinattes to be scanned 
    setpoint - the height at wich the tip begins
    KP_eff, KI - feedback coefficients
    grad - gradient of error graph (see report)'''
    
    #initial conditions for while loop and scanline
    i = 0
    feedbacked_image = [scanline[0]]
    delta_height_array = [] #height of probe
    error_array = []
    
    
    while i < (len(scanline) - 1):
        
        #For each point a difference in the height of the tip and the sample (scanline) is found 
        #this difference is tells the feedback mechanism to move the tip up or down 
        
        delta_height = (feedbacked_image[i] - scanline[i]) # the difference between probe and scanline
        delta_height_array.append(delta_height) #added to height array
        
        #creating an error curve for each point 
        error = error_signal(delta_height,setpoint,arb,n,grad) #using function from above 
        error_array.append(error)
        
        #finally calculating the feedback using foruma from report
        feedback = KP_eff*error + KI*np.mean(error_array)  #using error coefficients 
        feedbacked_image.append(feedbacked_image[i] + feedback) #feedback is added to the scanline

        i = i + 1 
    
    return(feedbacked_image) #new coordinates of scanline

# %%
# Illustration of error signal, displacement relationship - TEST CELL

#setting conditions - TEST
arb_trial = 5
setpoint_trial = 0
power = 1
grad = 3

#creating array of plotted values 
feedback_values = []

#creating an error signal to plot 
n = -30
i = n
while i <= (-n):
    feedback_val = error_signal(i,setpoint_trial,arb_trial,power,grad)
    feedback_values.append(feedback_val)
    i = i + 1
    
#Plotting figure 
fig, ax = plt.subplots()
ax.plot(np.arange(n,-(n-1),1),feedback_values,'-')
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def height_image_producer(Xlabels,Ylabels,reduced_sorted_bdf_filled,theta_in_degrees,r,noise_strength,
                          noise_mean,noise_variance,setpoint,arb,KP_eff,KI,n,grad,scanline_direction,Feedbacked):
    
    '''Produces an array representing height of the sample across all x and y. The two outputs are:
    height based on steric collision model (with noise) and height based on feedback mechanism. Inputs:
    Xlables, Ylables - grid of bins created by the `structure_data_extracter`
    reduced_sorted_bdf_filled - the binned date frame
    the tip position and dimenstion (theta and r)
    Noise - strenght, mean and variance 
    setpoint - initial height of tip
    KP_eff, KI - feedback coefficients
    grad - gradient of error graph (see report)'''
    
    #setting up arrays
    H= [] #initial array for steric collision model
    H2=[] #initial array for feedback mechanism
    
    #creating a grid 
    for n in range(len(Ylabels)):
        H_sub_array=[]  # Each H_sub_array is effectively a scanline at a given value of Y
        
        for i in range(len(Xlabels)):
            
            #Calculating the height difference using functions above:
            H_sub_array_element = height_diff_calc_three_dee(Xlabels,Ylabels,reduced_sorted_bdf_filled,
                                                             Xlabels[i],Ylabels[n],theta_in_degrees,r)
            H_sub_array.append(H_sub_array_element)
            
            
        # Adding in noise to each scanline:
        noise_array = noise_strength*random.normal(noise_mean,noise_variance,size=len(H_sub_array))  #Gaussian    
        H_sub_array_with_noise = H_sub_array + noise_array #aimply adding noise to sample
        
        
        #### Now considering scanning Right to Left:
        
        # Different noise on second scan back
        new_noise_array = noise_strength*random.normal(noise_mean,noise_variance,size=len(H_sub_array)) 
        reverse_H_sub_array = H_sub_array[::-1] #the new array is reversed but the code stays the same
        reverse_H_sub_array_with_noise = reverse_H_sub_array + new_noise_array
        
        if Feedbacked == True:
        
            # Adding in Feedback to each scanline:
            H_sub_array_with_noise_and_feedback = feedback2d(H_sub_array_with_noise,setpoint,arb,KP_eff,KI,n,grad)
            reverse_scanline_H_sub_array = feedback2d(reverse_H_sub_array_with_noise, setpoint,arb,KP_eff,KI,n,grad)[::-1]

        
        else:
            H_sub_array_with_noise_and_feedback = 0
            reverse_scanline_H_sub_array = 0

        ##### Merging both feedback lines:
        H_sub_array_both_directions = (1/2)*(np.array(H_sub_array_with_noise_and_feedback) \
                                             + np.array(reverse_scanline_H_sub_array))     

            
        #### Merging both scanlines with noise:
        
        H_sub_array_with_noise_both_directions = (1/2)*(H_sub_array_with_noise + reverse_H_sub_array_with_noise)
        H.append(H_sub_array_with_noise)
        
        #assigning the arrays to an appropriate designation
        if scanline_direction == 'left_to_right':
            H2.append(H_sub_array_with_noise_and_feedback)
                        
        if scanline_direction == 'right_to_left':
            H2.append(reverse_scanline_H_sub_array)
                    
        if scanline_direction == 'both':
            H2.append(H_sub_array_both_directions)
                   
    H_array = np.array(H) #height based on steric collision model
    H2 = np.array(H2) #height based on feedback mechanism 
    
    return(H_array,H2) #outputs both methods

# %%
@profile
def psuedo_AFM_image_producer(structure, r, theta_in_degrees, xstep, ystep, extension, x_rot, y_rot, z_rot, 
                              noise_strength,noise_mean,noise_variance,setpoint,arb,KP_eff,KI,n,grad,
                              scanline_direction,ThreeDplot, Heatmap,Feedbacked,molecule_view, view_style,
                              Simulated_Surface,DotPlot,Overlay_Plot,relative_contrast,feedback_graph):
    
    '''Final function which brings everything together. User inputs all variables and all results 
    are outputted. The user gets a feedback plot of the error values, A heatmap of the AFM image,
    and 3D plots of the sample surface. Inputs are:
    ALL INPUTS MENTIONED IN FUNCTIONS ABOVE'''
    
    #First the data is extracted from the PDB file using function
    structure_df_check,Xlabels,Ylabels,new_df,sample_height_max,post_adj_view = structure_data_extracter(structure,xstep,ystep,
                                                                                                         extension, x_rot,
                                                                                                         y_rot,z_rot, view_style)
    #now the height of the tip at all points is being found 
    Z_AFM, feedbacked_H = height_image_producer(Xlabels,Ylabels,structure_df_check,theta_in_degrees,
                                                r,noise_strength,noise_mean,noise_variance,setpoint,
                                                arb,KP_eff,KI,n,grad,scanline_direction,Feedbacked)
    
    
    #### Depending what the user needs - Heatmap with feedback and noise
    if Feedbacked == True:
        
        #plotting AFM with feedback + noise
        fig=plt.figure()
        fig.suptitle('AFM image w/feedback + noise', fontsize=16)
        x = Xlabels
        y = Ylabels
        X, Y = np.meshgrid(x, y)
        
                ### This section is for adjusting the contrast in colour map image ###
        feedbacked_H_range = feedbacked_H.max()-feedbacked_H.min()
        vmin_value = feedbacked_H_range * relative_contrast
        plt.contourf(X,Y,feedbacked_H,levels=100, cmap='afmhot', vmin = vmin_value) #creating contours
        plt.colorbar()
    
    
    #### A heatmap of the AFM image is a good visual tool, so it will be included 
    if Heatmap == True:
        
        #plotting heatmap without feedback
        fig = plt.figure()
        fig.suptitle(' AFM image, no feedback ')      
        x = Xlabels
        y = Ylabels
        X, Y = np.meshgrid(x, y)
        
                ### This section is for adjusting the contrast in colour map image ###
        Z_AFM_range = Z_AFM.max()-Z_AFM.min()
        vmin_value = Z_AFM_range * relative_contrast
        plt.contourf(X,Y,Z_AFM,levels=100, cmap='afmhot', vmin = vmin_value) #creating contours - as above
        plt.colorbar()
          
            
    #### 3D plot of sample
    if ThreeDplot == True:
        
        #plotting a 3d plot withno feedback
        fig=plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        fig.suptitle('Three dimensional plot of AFM image (no feedback)')
        ax.set_xlabel('$X$', fontsize= 20, rotation = 0)
        ax.set_ylabel('$Y$', fontsize = 20, rotation = 0)
        ax.set_zlabel('Height $\AA$', fontsize=20, rotation= 0)
        ax.plot_surface(X,Y,Z_AFM, rstride = 1, cstride = 1) #plotting Z_AFM on top of X and Y plane
     
    
    ####
    if Simulated_Surface == True:
        
        Z= []
        for n in range(len(Ylabels)):
            Z_sub_array=[]
            for i in range(len(Xlabels)):
                Z_sub_array_element = structure_df_check[i*len(Ylabels)+n]
                Z_sub_array.append(Z_sub_array_element)
            Z.append(Z_sub_array)

        Z_array = np.array(Z)
        fig=plt.figure()
        ax = fig.add_subplot(111, projection='3d')

        x = Xlabels
        y = Ylabels
        X, Y = np.meshgrid(x, y)
        
        ax.set_xlabel('$X$', fontsize= 20, rotation = 0)
        ax.set_ylabel('$Y$', fontsize = 20, rotation = 0)
        ax.set_zlabel('Height $\AA$', fontsize=20, rotation= 0)
        ax.plot_surface(X,Y,Z_array, rstride = 1, cstride = 1)
        
        
    #### Dot plot of atoms in the protein
    if DotPlot == True:
        
        #plotting a dotlpot 
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')

        #new data frame of binned atoms 
        X = new_df['X']
        Y = new_df['Y']
        Z = new_df['Z']

        #scatter plot of all coordinate pairs
        ax.scatter(X,Y,Z, marker='.' ,alpha=0.6,color='r', cmap='viridis')
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Height')
        plt.show()
        s = 30
        ax.auto_scale_xyz([-s, s], [-s, s], [0, 50])
        
        
    #### The dot plot and the 3D surface will be overlayed for comparison
    if Overlay_Plot == True:
        
        # setting up the plot and axes 
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        X = new_df['X']
        Y = new_df['Y']
        Z = new_df['Z']

        #plotting the scatter of atoms 
        ax.scatter(X,Y,Z, marker='.' ,alpha=0.6,color='r', cmap='viridis') 
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Height')
        
        #repeating code for plotting the surface 
        Z= []
        for n in range(len(Ylabels)):
            Z_sub_array=[]
            for i in range(len(Xlabels)):
                Z_sub_array_element = structure_df_check[i*len(Ylabels)+n]
                Z_sub_array.append(Z_sub_array_element)
            Z.append(Z_sub_array)

        #all together on the grid
        Z_array = np.array(Z)
        x = Xlabels
        y = Ylabels
        X, Y = np.meshgrid(x, y)
        
        #setting up and labelling axes
        ax.set_xlabel('$X$', fontsize= 20, rotation = 0)
        ax.set_ylabel('$Y$', fontsize = 20, rotation = 0)
        ax.set_zlabel('Height $\AA$', fontsize=20, rotation= 0)
        
        #plttong surface
        ax.plot_surface(X,Y,Z_array, rstride = 1, cstride = 1, alpha = 0.65)
    
    
    #### Feedback/error graph of the sample
    if feedback_graph == True:
        
        #collecting feedback values 
        feedback_values = []

        #setting up initial conditions
        n = -30 #n is the range in x 
        i = n
        while i <= (-n):
            feedback_val = error_signal(i,setpoint,arb,n,grad) #using function defined above
            feedback_values.append(feedback_val)
            i = i + 1

        #plotting the linear graph
        fig, ax = plt.subplots()
        ax.plot(np.arange(n,-(n-1),1),feedback_values,'-')
        ax.grid(True, which='both')
        ax.axhline(y=0, color='k')
        ax.axvline(x=0, color='k')
        
    #### 
    if molecule_view == True:
        return(post_adj_view)
    
#plotting everything
plt.show()

# %%
def PDB_getter(structure_name):
    
    '''This function imports the relevant PDB file (and takes care of the directory) 
    in which it is saved etc for the user, returning the structure and the view using a widget.
    The only input is the name of the PDB file (four letters)'''

    #command to get four letter PDB file using Bio.Python
    pdbl.retrieve_pdb_file(structure_name)
    
    #creating a folder on the Users system - location is the same as the Notebook file's
    split_structure_name = list(structure_name)
    structure_file_folder = str(split_structure_name[1]) + str(split_structure_name[2])
    c ='.cif' #filetype prefix.
    the_slashes = '/' #compatible with MAC not WINDOWS. for WINDOWS use: '\\'
    d = 'pdb:' 
    directory = str(os.getcwd())
    
    #retrieving file from the location it was just saved in
    file_loc = directory + the_slashes + structure_file_folder + the_slashes + structure_name + c
    structure = parser.get_structure(structure_name, file_loc)  # defining structure, 'name we give it' and 'location'
    viewer_name = d + structure_name
    
    #plotting the relevant structure using py3Dmol 
    view = py3Dmol.view(query=viewer_name).setStyle({'cartoon':{'color':'spectrum'}})
    
    return(structure,view) #returns the structure (input for other functions) and views the protein

# %% [markdown]
# ## Inputs & Outputs:
#
#
# Here the user has two choice. They can choose to insert a PDB file (recommended) by either importing it from their device or by insterting the four digit code corresponding to their desired protein. They can also choose to image any three-dimensional shape. To do this the user needs to first create this shape through any means that outputs coordinate arrays for x, y and z. These, must then be constructed as an array named as structure1.

# %%
#### USER INPUT SECTION ####

#Ask the user if they want to input a CSV or a PDB file

manual = input('would you like to import a PDB (type "pdb") file or a CSV file (type "csv")')
#User is asked to choose between a manual PDB file input or the four character code from the database

if manual == 'csv':
    
    csv_loc = input('please input the location of your csv file:')
    structure_name = input('Please assign a name to this structure: ')
    print('Please proceed to load the viewer')
    
if manual == 'pdb':

    manual = input('Would you like to manually upload a pdb file (enter yes), or input the 4-digit PDB name (enter no):') 

    #PDB four-character code input
    if manual == 'no': 
        four_digit = False

        #User interaction to enter PDB code 
        structure_name = input('Please input the 4-digit name of the protein you would like to use:')

        #making sure the input string has four characters
        while four_digit == False:
            if len(structure_name) != 4:
                print('ERROR, the name you have entered is not 4-digits, please enter a new one:') 
                structure_name = input('Please input the 4-digit name of the protein you would like to use:')
            else:
                four_digit = True 
                print('You have entered a four-digit name, please proceed to load the viewer') 
                
    #Manual entry
    
    if manual == 'yes':

        #User is now asked to insert file location of where the PDB file is located
        structure_name = input('Please assign a name to this structure: ')
        file_loc = input('Please input the file location: ')

else:
    print('The input is not in the correct format, please try again.')
    
    
    #else:
    #    print('You have not input either "yes" (to manually upload a PDB) or "no" (to load the PDB via its name), PLEASE RE-RUN THIS CELL')
# Out:
# would you like to import a PDB (type "pdb") file or a CSV file (type "csv")csv
# please input the location of your csv file:football.csv
# Please assign a name to this structure: hi
# Please proceed to load the viewer
# The input is not in the correct format, please try again.

# %%
# %%capture  
## Adding the above hides all the error messages from the cell

#get PDB files usinf function above 
if manual == 'csv':
    
    allcoord = np.loadtxt(csv_loc, delimiter=',')
    all_flat = allcoord.flatten(order='A')

    X_all = all_flat[0::3]
    Y_all = all_flat[1::3]
    Z_all = all_flat[2::3]

    structure1 = (X_all, Y_all, Z_all)

if manual == 'no':
    structure1,view = PDB_getter(structure_name)

#user inputs location and structure name 
if manual == 'yes':
    structure1 = pdb_parser.get_structure(structure_name, file_loc)  

else:
    print ('please re-run the previous cell')

# %%
new_view = nv.show_biopython(structure1)
new_view

### Issue with y axis flip apparent here
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-90f1239f959f> in <module>
# ----> 1 new_view = nv.show_biopython(structure1)
#       2 new_view
#       3
#       4 ### Issue with y axis flip apparent here
#
# /opt/anaconda3/lib/python3.7/site-packages/nglview/show.py in show_biopython(entity, **kwargs)
#     450     '''
#     451     entity = BiopythonStructure(entity)
# --> 452     return NGLWidget(entity, **kwargs)
#     453
#     454
#
# /opt/anaconda3/lib/python3.7/site-packages/nglview/widget.py in __init__(self, structure, representations, parameters, **kwargs)
#     243         else:
#     244             if structure is not None:
# --> 245                 self.add_structure(structure, **kwargs)
#     246
#     247         if representations:
#
# /opt/anaconda3/lib/python3.7/site-packages/nglview/widget.py in add_structure(self, structure, **kwargs)
#    1111         if not isinstance(structure, Structure):
#    1112             raise ValueError(f'{structure} is not an instance of Structure')
# -> 1113         self._load_data(structure, **kwargs)
#    1114         self._ngl_component_ids.append(structure.id)
#    1115         if self.n_components > 1:
#
# /opt/anaconda3/lib/python3.7/site-packages/nglview/widget.py in _load_data(self, obj, **kwargs)
#    1229         if not is_url:
#    1230             if hasattr(obj, 'get_structure_string'):
# -> 1231                 blob = obj.get_structure_string()
#    1232                 kwargs2['ext'] = obj.ext
#    1233                 passing_buffer = True
#
# /opt/anaconda3/lib/python3.7/site-packages/nglview/adaptor.py in get_structure_string(self)
#     195         from io import StringIO
#     196         io_pdb = PDBIO()
# --> 197         io_pdb.set_structure(self._entity)
#     198         io_str = StringIO()
#     199         io_pdb.save(io_str)
#
# /opt/anaconda3/lib/python3.7/site-packages/Bio/PDB/PDBIO.py in set_structure(self, pdb_object)
#      66         # a Residue, build Structure/Model/Chain.
#      67
# ---> 68         if pdb_object.level == "S":
#      69             structure = pdb_object
#      70         else:  # Not a Structure
#
# AttributeError: 'tuple' object has no attribute 'level'

# %%
#setting up the view 
new_view.clear_representations()
new_view.add_representation('spacefill', selection='protein')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f03de62fa426> in <module>
#       1 #setting up the view
# ----> 2 new_view.clear_representations()
#       3 new_view.add_representation('spacefill', selection='protein')
#
# NameError: name 'new_view' is not defined

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
#Using the final function and user inputs to create final results 
import time


#t0 = time.time()

psuedo_AFM_image_producer(structure1,r=1,theta_in_degrees=2,xstep=4,ystep=4, extension = 30, x_rot = 0, y_rot = 0,z_rot = 0, noise_strength = 0, noise_mean = 3,noise_variance = 0.5, setpoint = 0 ,arb = 10 ,KP_eff = 0.4 , KI = 0.6 ,n=1, grad = 1, scanline_direction='both',ThreeDplot = True, Feedbacked = True, Heatmap = True, molecule_view = True, view_style = 'spacefill', Simulated_Surface = True, DotPlot = True,Overlay_Plot=True, relative_contrast = 0.0, feedback_graph = True)
 
#t1 = time.time()
#total = t1-t0
# Out:
# df_from_structure 0.003017902374267578
# 0.033651113510131836
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
#          15141125 function calls (15134547 primitive calls) in 12.315 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   12.316   12.316 <ipython-input-37-2dc604f78b56>:1(psuedo_AFM_image_producer)
#         1    0.015    0.015   11.661   11.661 <ipython-input-12-695533d0234c>:1(height_image_producer)
#       484    0.249    0.001   11.630    0.024 <ipython-input-36-4e131b9ee669>:3(height_diff_calc_three_dee)
#    235224    0.378    0.000    8.442    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:868(__getitem__)
#    235224    0.633    0.000    7.935    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1473(get_value)
#    235224    0.099    0.000    6.081    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1478(_try_mi)
#    235224    0.202    0.000    5.981    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2600(get_loc)
#    235224    0.391    0.000    5.722    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2849(_get_level_indexer)
#    235224    0.219    0.000    4.837    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2575(_get_loc_single_level_index)
#    235224    0.182    0.000    4.338    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/category.py:469(get_loc)
#    235224    0.764    0.000    3.740    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:495(get_loc)
#       484    0.213    0.000    2.889    0.006 <ipython-input-5-75b12322485d>:39(threedeetipcreater)
#    234256    2.618    0.000    2.637    0.000 <ipython-input-5-75b12322485d>:3(threedeetipheightcalc)
#    235300    0.139    0.000    1.912    0.000 <__array_function__ internals>:2(all)
# 244775/244215    0.326    0.000    1.802    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    235300    0.163    0.000    1.436    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2324(all)
#    236582    0.369    0.000    1.288    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:73(_wrapreduction)
#    235246    0.316    0.000    1.034    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:2637(get_loc)
#    470458    0.319    0.000    0.896    0.000 {pandas._libs.lib.values_from_object}
#    235252    0.213    0.000    0.742    0.000 {method 'all' of 'numpy.generic' objects}
#    470472    0.617    0.000    0.617    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#    235224    0.094    0.000    0.577    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:520(_internal_get_values)
#    235342    0.076    0.000    0.529    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:47(_all)
#    235224    0.197    0.000    0.483    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1568(get_values)
#    237846    0.466    0.000    0.466    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    470464    0.319    0.000    0.424    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/frozen.py:66(__getitem__)
#    235234    0.087    0.000    0.415    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/extension.py:57(fget)
# 485431/485425    0.145    0.000    0.378    0.000 {built-in method builtins.getattr}
#         9    0.000    0.000    0.263    0.029 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:1261(add_subplot)
#         9    0.000    0.000    0.262    0.029 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py:18(__init__)
#         9    0.000    0.000    0.256    0.028 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:421(__init__)
#    235265    0.077    0.000    0.255    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:49(isna)
#         2    0.000    0.000    0.252    0.126 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:2527(contourf)
#    235224    0.247    0.000    0.247    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#    235242    0.137    0.000    0.233    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:396(categories)
#         9    0.001    0.000    0.197    0.022 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:960(cla)
#    235265    0.116    0.000    0.179    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:132(_isna_new)
#    235224    0.090    0.000    0.175    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py:240(to_dense)
#         6    0.000    0.000    0.159    0.026 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:1596(inner)
#    971774    0.147    0.000    0.150    0.000 {built-in method builtins.isinstance}
#         6    0.000    0.000    0.138    0.023 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:908(gca)
#         8    0.000    0.000    0.138    0.017 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:1888(gca)
# 247289/247263    0.121    0.000    0.121    0.000 {built-in method numpy.array}
#         2    0.000    0.000    0.114    0.057 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6427(contourf)
#         2    0.002    0.001    0.111    0.056 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:766(__init__)
#       878    0.001    0.000    0.103    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1236(__add__)
#       882    0.001    0.000    0.103    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:2470(composite_transform_factory)
#      1879    0.101    0.000    0.102    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:164(set_children)
#    235226    0.072    0.000    0.101    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:4723(_maybe_cast_indexer)
#       882    0.002    0.000    0.101    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:2299(__init__)
#    235242    0.072    0.000    0.097    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/common.py:335(apply_if_callable)
#         9    0.000    0.000    0.096    0.011 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:1133(_set_title_offset_trans)
#    236582    0.092    0.000    0.092    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:74(<dictcomp>)
#    235600    0.084    0.000    0.086    0.000 {method 'view' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.085    0.043 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:2077(colorbar)
#         2    0.000    0.000    0.085    0.043 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2190(colorbar)
#        70    0.002    0.000    0.080    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:56(__init__)
#    705761    0.078    0.000    0.079    0.000 {pandas._libs.lib.is_scalar}
#    235224    0.077    0.000    0.077    0.000 {built-in method pandas._libs.index.get_value_at}
#       201    0.001    0.000    0.071    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:1858(add_collection)
#         4    0.000    0.000    0.069    0.017 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:49(__init__)
#     54/44    0.000    0.000    0.066    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:658(__get__)
#         7    0.000    0.000    0.057    0.008 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:426(figure)
#        22    0.000    0.000    0.057    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:945(set_clip_path)
#        74    0.001    0.000    0.056    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:862(set_tick_params)
#    235279    0.055    0.000    0.055    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1520(_block)
#       213    0.003    0.000    0.054    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:90(__init__)
#         7    0.000    0.000    0.054    0.008 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py:3253(new_figure_manager)
#       196    0.001    0.000    0.053    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:874(__init__)
#        21    0.000    0.000    0.052    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:87(show)
#       340    0.003    0.000    0.052    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:709(set_clip_path)
#         7    0.000    0.000    0.051    0.007 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:229(new_figure_manager_given_figure)
#    235377    0.050    0.000    0.050    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:446(dtype)
#    505474    0.049    0.000    0.049    0.000 {method 'append' of 'list' objects}
#    470464    0.049    0.000    0.049    0.000 {function FrozenList.__getitem__ at 0x7fe024f76a70}
#       225    0.005    0.000    0.047    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py:273(__init__)
#        39    0.000    0.000    0.047    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1928(_get_tick)
#    235342    0.046    0.000    0.046    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:588(categories)
#         2    0.000    0.000    0.045    0.023 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:1626(colorbar_factory)
#         2    0.000    0.000    0.045    0.023 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:1155(__init__)
#         4    0.000    0.000    0.044    0.011 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:1075(cla)
#    235242    0.044    0.000    0.044    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:794(codes)
#        13    0.000    0.000    0.043    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:2744(grid)
#        26    0.000    0.000    0.043    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1432(grid)
#         3    0.002    0.001    0.043    0.014 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:1518(plot_surface)
#         2    0.000    0.000    0.041    0.021 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:2274(scatter)
#    235254    0.040    0.000    0.040    0.000 {built-in method pandas._libs.missing.checknull}
#         2    0.000    0.000    0.040    0.020 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:1471(make_axes_gridspec)
#      1401    0.006    0.000    0.039    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:942(update)
#       338    0.001    0.000    0.039    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:209(get_transform)
#         2    0.000    0.000    0.039    0.019 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:4311(scatter)
#         2    0.000    0.000    0.037    0.018 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:398(__init__)
#         5    0.000    0.000    0.036    0.007 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:181(get_datalim)
#    235300    0.035    0.000    0.035    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2320(_all_dispatcher)
#       338    0.000    0.000    0.035    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:757(get_patch_transform)
#         2    0.000    0.000    0.035    0.017 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/path.py:933(get_path_collection_extents)
#         2    0.029    0.014    0.035    0.017 {built-in method matplotlib._path.get_path_collection_extents}
#       338    0.002    0.000    0.035    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:728(_update_patch_transform)
# 269476/269256    0.034    0.000    0.035    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.034    0.034 <ipython-input-35-58739acece28>:5(structure_data_extracter)
#        31    0.000    0.000    0.034    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:2218(_get_tick)
#    248334    0.032    0.000    0.032    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.032    0.016 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:476(draw_all)
#       802    0.003    0.000    0.031    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:651(_set_facecolor)
#    235264    0.031    0.000    0.031    0.000 {pandas._libs.lib.is_bool}
#    235256    0.029    0.000    0.029    0.000 {pandas._libs.lib.is_float}
#      1234    0.004    0.000    0.028    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:254(to_rgba_array)
#         7    0.000    0.000    0.027    0.004 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:120(_create_comm)
#      1913    0.005    0.000    0.026    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:149(to_rgba)
#    236101    0.025    0.000    0.025    0.000 {built-in method builtins.callable}
#       130    0.002    0.000    0.025    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:332(_apply_params)
#        84    0.001    0.000    0.025    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:819(cla)
#         1    0.000    0.000    0.024    0.024 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:1090(subplots)
#         2    0.000    0.000    0.024    0.012 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:695(_config_axes)
#       604    0.001    0.000    0.023    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:664(set_facecolor)
#       650    0.002    0.000    0.023    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:1064(set)
#         2    0.000    0.000    0.022    0.011 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:593(update_ticks)
#        14    0.000    0.000    0.021    0.001 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:131(display)
#         7    0.000    0.000    0.020    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:81(display_js)
#         7    0.000    0.000    0.020    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:161(__init__)
#       338    0.001    0.000    0.020    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1950(rotate_deg_around)
#       132    0.000    0.000    0.019    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:798(_set_scale)
#    234606    0.019    0.000    0.019    0.000 {built-in method builtins.abs}
#         6    0.000    0.000    0.019    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1741(set_ticks)
#        56    0.001    0.000    0.019    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:657(send)
#         6    0.000    0.000    0.018    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1404(get_major_ticks)
#      1323    0.003    0.000    0.018    0.000 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:1646(<listcomp>)
#       132    0.001    0.000    0.018    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/scale.py:86(set_default_locators_and_formatters)
#         6    0.001    0.000    0.018    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1121(changed)
# 19010/14922    0.011    0.000    0.018    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:219(stale)
#         1    0.000    0.000    0.018    0.018 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:1427(subplots)
#        42    0.000    0.000    0.016    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py:61(_publish_msg)
#      1401    0.001    0.000    0.016    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:974(<listcomp>)
#      3969    0.007    0.000    0.015    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2002(_array_perimeter)
#        54    0.000    0.000    0.015    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:230(set_clip_path)
#        14    0.000    0.000    0.015    0.001 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:81(publish_display_data)
#       659    0.001    0.000    0.015    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:946(_update_property)
#        14    0.000    0.000    0.015    0.001 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py:94(publish)
#        44    0.002    0.000    0.014    0.000 <ipython-input-10-cd8430604e64>:21(feedback2d)
#       275    0.000    0.000    0.014    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:223(__init__)
#         1    0.000    0.000    0.014    0.014 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1365(f)
#         1    0.000    0.000    0.014    0.014 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:874(_cython_agg_general)
#         4    0.000    0.000    0.014    0.003 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:201(_init_axis)
#        35    0.000    0.000    0.014    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py:486(_send_event)
#        35    0.000    0.000    0.014    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:198(send_json)
#        35    0.000    0.000    0.013    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py:120(send)
#       132    0.000    0.000    0.013    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:2662(__init__)
#         2    0.000    0.000    0.013    0.007 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4299(reindex)
#       275    0.001    0.000    0.013    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:292(set_marker)
#       134    0.000    0.000    0.013    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:1896(__init__)
#         1    0.000    0.000    0.013    0.013 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py:363(_wrap_aggregated_output)
#        39    0.000    0.000    0.013    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:458(_get_tick1line)
#       134    0.001    0.000    0.012    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:1971(set_params)
#        22    0.000    0.000    0.012    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:715(__init__)
#         1    0.000    0.000    0.012    0.012 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2444(_reindex_output)
#      1219    0.001    0.000    0.012    0.000 <__array_function__ internals>:2(dot)
#       651    0.009    0.000    0.012    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1702(normalize_kwargs)
#       198    0.001    0.000    0.011    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:730(set_alpha)
#       104    0.000    0.000    0.011    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:842(reset_ticks)
#       924    0.001    0.000    0.011    0.000 <__array_function__ internals>:2(mean)
#      4249    0.002    0.000    0.011    0.000 <__array_function__ internals>:2(concatenate)
#       214    0.002    0.000    0.011    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:121(__init__)
#        39    0.000    0.000    0.011    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:484(_get_gridline)
#         1    0.000    0.000    0.011    0.011 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4027(reindex)
#       676    0.002    0.000    0.011    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1962(translate)
#         1    0.000    0.000    0.011    0.011 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4547(_reindex_axes)
#       550    0.001    0.000    0.011    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:245(_recache)
#        18    0.000    0.000    0.010    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:2918(tick_params)
#         5    0.000    0.000    0.010    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:594(_init_axis)
#       561    0.001    0.000    0.010    0.000 <__array_function__ internals>:2(amin)
#        39    0.000    0.000    0.010    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:469(_get_tick2line)
#     14229    0.007    0.000    0.010    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:811(__getitem__)
#       539    0.001    0.000    0.010    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:170(update)
#         1    0.000    0.000    0.010    0.010 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2373(reindex)
#       924    0.002    0.000    0.010    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3231(mean)
#         1    0.000    0.000    0.010    0.010 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2330(get_indexer)
#         1    0.000    0.000    0.010    0.010 {method 'get_indexer' of 'pandas._libs.index.BaseMultiIndexCodesEngine' objects}
#        13    0.000    0.000    0.010    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:2388(autoscale_view)
#         6    0.000    0.000    0.009    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py:386(autoscale_None)
#        56    0.000    0.000    0.009    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:598(serialize)
#       828    0.006    0.000    0.009    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:74(__init__)
#       497    0.005    0.000    0.009    0.000 /opt/anaconda3/lib/python3.7/site-packages/cycler.py:349(by_key)
#        31    0.000    0.000    0.009    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:602(_get_gridline)
#        26    0.001    0.000    0.009    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:2425(handle_single_axis)
#       561    0.001    0.000    0.009    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2676(amin)
#       642    0.001    0.000    0.009    0.000 <__array_function__ internals>:2(any)
#         7    0.000    0.000    0.008    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:107(get_javascript)
#         2    0.000    0.000    0.008    0.004 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/category.py:635(get_indexer)
#       338    0.002    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1930(rotate_deg)
#        68    0.001    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:42(__init__)
#       924    0.003    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:134(_mean)
#        21    0.000    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py:155(draw_idle)
#        21    0.000    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py:345(send_event)
#      3303    0.002    0.000    0.008    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.008    0.003 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py:585(__init__)
#         3    0.000    0.000    0.008    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:1024(__init__)
#         9    0.000    0.000    0.008    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:942(_gen_axes_spines)
#        45    0.000    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:957(<genexpr>)
#        31    0.000    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:573(_get_tick1line)
#        36    0.000    0.000    0.008    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/spines.py:536(linear_spine)
#       246    0.002    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:620(__init__)
# 2862/2844    0.001    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:16(asarray)
#      1527    0.002    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/contextlib.py:107(__enter__)
#       642    0.001    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2236(any)
#        73    0.000    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py:1021(get_path)
#       778    0.003    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:726(__init__)
#        73    0.002    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py:667(recache)
#        12    0.000    0.000    0.007    0.001 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axis3d.py:115(init3d)
#      2644    0.003    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:49(_stale_axes_callback)
#         3    0.001    0.000    0.007    0.002 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py:650(set_verts)
#         7    0.000    0.000    0.007    0.001 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py:50(__init__)
#        14    0.000    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py:77(_flush_streams)
#        56    0.000    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:564(msg)
#        12    0.000    0.000    0.007    0.001 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axis3d.py:67(__init__)
#       181    0.001    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1976(scale)
#        28    0.000    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py:336(flush)
#       338    0.003    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1914(rotate)
#        31    0.000    0.000    0.007    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:588(_get_tick2line)
#        36    0.000    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/spines.py:34(__init__)
#         3    0.006    0.002    0.006    0.002 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:1687(_generate_normals)
#        56    0.000    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:561(msg_header)
#         7    0.002    0.000    0.006    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py:448(get_javascript)
#       132    0.002    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:1948(_validate_steps)
#         7    0.000    0.000    0.006    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py:425(add_web_socket)
#         2    0.000    0.000    0.006    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:767(_add_solids)
#         2    0.000    0.000    0.006    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6000(pcolormesh)
#      1527    0.002    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/contextlib.py:237(helper)
#       357    0.001    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:762(unit)
#      2802    0.004    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2041(_setattr_cm)
#       224    0.000    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:102(<lambda>)
#        70    0.006    0.000    0.006    0.000 {built-in method posix.urandom}
#       224    0.000    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/zmq/utils/jsonapi.py:31(dumps)
#       213    0.001    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:483(set_linewidth)
#         3    0.003    0.001    0.006    0.002 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py:628(get_vector)
#        14    0.000    0.000    0.006    0.000 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py:89(format)
#      1913    0.001    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:115(_is_nth_color)
#        56    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:509(msg_id)
#        39    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:425(_get_text1)
#       280    0.001    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/json/__init__.py:183(dumps)
#        14    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/pathlib.py:1212(read_text)
#        56    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:121(new_id)
#       348    0.002    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/path.py:96(__init__)
#       134    0.001    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:1963(_staircase)
#      1351    0.002    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:126(invalidate)
#       168    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py:220(catch_format_error)
#       225    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py:1243(set_markerfacecolor)
#       119    0.001    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py:197(schedule)
#        28    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.005    0.002 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py:32(cut)
#       364    0.001    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:788(from_extents)
#        28    0.000    0.000    0.005    0.000 /opt/anaconda3/lib/python3.7/threading.py:264(wait)
#         6    0.000    0.000    0.005    0.001 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:488(auto_scale_xyz)
#       571    0.001    0.000    0.005    0.000 <__array_function__ internals>:2(atleast_1d)
#       134    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(hstack)
#       259    0.004    0.000    0.004    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.004    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:573(_reset_locator_formatter_scale)
#       280    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/json/encoder.py:182(encode)
#       392    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:185(_to_rgba_no_colorcycle)
#         2    0.004    0.002    0.004    0.002 {method 'get_indexer_non_unique' of 'pandas._libs.index.IndexEngine' objects}
#         7    0.000    0.000    0.004    0.001 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py:80(open)
#      1527    0.002    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/contextlib.py:116(__exit__)
#         8    0.000    0.000    0.004    0.001 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:1360(tick_params)
#      1527    0.004    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/contextlib.py:81(__init__)
#       194    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1114(_make_paths)
#        39    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:442(_get_text2)
#        31    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:543(_get_text1)
#        11    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py:122(update_params)
#     17/11    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/gridspec.py:486(get_position)
#         2    0.000    0.000    0.004    0.002 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py:354(_bins_to_cuts)
# 3395/3388    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py:545(__get__)
#         8    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:502(autoscale_view)
#      1088    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/re.py:170(match)
#     31/16    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:276(__new__)
#       194    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1116(<listcomp>)
#       411    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:689(_set_edgecolor)
#        31    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:558(_get_text2)
#       134    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py:286(hstack)
#       273    0.003    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/json/encoder.py:204(iterencode)
#        14    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/pathlib.py:1194(open)
#        20    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/spines.py:214(register_axis)
#        14    0.001    0.000    0.004    0.000 {built-in method io.open}
#       119    0.004    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py:342(send)
#      2077    0.001    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:88(asanyarray)
#      1624    0.002    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1683(__init__)
#       217    0.000    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:303(_set_facecolor)
# 2072/1351    0.003    0.000    0.004    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:137(_invalidate_internal)
#     19/15    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py:1565(take_nd)
#      3747    0.003    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:82(__init__)
#         1    0.000    0.000    0.003    0.003 <ipython-input-7-7a15c404a20b>:1(df_from_structure)
#       571    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py:25(atleast_1d)
#         3    0.000    0.000    0.003    0.001 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1224(reindex_indexer)
#       127    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(column_stack)
#        16    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1374(_copy_tick_props)
#     17/11    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/gridspec.py:86(get_grid_positions)
#        36    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/spines.py:226(cla)
#       215    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py:193(__init__)
#        14    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/pathlib.py:1056(_opener)
#         2    0.000    0.000    0.003    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1436(_process_args)
#        14    0.003    0.000    0.003    0.000 {built-in method posix.open}
#      4121    0.002    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:338(pchanged)
#         2    0.000    0.000    0.003    0.001 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/category.py:315(equals)
#        56    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py:262(send_multipart)
#       564    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1819(__init__)
#         1    0.000    0.000    0.003    0.003 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3858(drop)
#         1    0.000    0.000    0.003    0.003 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:3907(drop)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/IPython/utils/decorators.py:41(wrapper)
#         1    0.000    0.000    0.003    0.003 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:3943(_drop_axis)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py:3271(draw_if_interactive)
#        39    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:768(_set_tickdown)
#     19010    0.003    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:774(get_animated)
#      1367    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py:209(send_multipart)
# 3171/3164    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py:526(get)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:239(trigger_manager_draw)
#        13    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:944(__call__)
#       426    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:584(_bcast_lwls)
#       126    0.000    0.000    0.003    0.000 </opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9>:1(__call__)
#    308/98    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py:109(json_clean)
#     14311    0.003    0.000    0.003    0.000 {function RcParams.__getitem__ at 0x7fe023f6c170}
#         1    0.000    0.000    0.003    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:251(show)
#         1    0.000    0.000    0.003    0.003 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_nbagg.py:243(show)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py:415(resize)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py:950(__new__)
#        12    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:1226(__init__)
#         2    0.000    0.000    0.003    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1484(_get_allsegs_and_allkinds)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py:982(setup_instance)
#         3    0.000    0.000    0.003    0.001 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py:1731(_shade_colors)
#       225    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py:1257(set_markerfacecoloralt)
#       127    0.001    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/shape_base.py:612(column_stack)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:275(__init__)
#         7    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py:961(setup_instance)
#       126    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py:331(__call__)
#         2    0.000    0.000    0.003    0.001 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4584(_reindex_with_indexers)
#         6    0.000    0.000    0.003    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py:223(to_rgba)
#       154    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py:374(lookup)
#         3    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:1894(add_line)
#       213    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:717(set_edgecolor)
#       225    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py:1146(set_linestyle)
#        18    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:3161(set_xlim)
#        39    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:762(_set_tickup)
#         1    0.000    0.000    0.002    0.002 /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:225(wrapper)
#         1    0.000    0.000    0.002    0.002 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3837(reindex)
#        16    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:685(__init__)
#        56    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py:583(sign)
#         1    0.000    0.000    0.002    0.002 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:1432(plot)
#        91    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:2782(__new__)
#       363    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:994(__init__)
#        15    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:3080(set_xbound)
#        16    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:965(__init__)
#       194    0.002    0.000    0.002    0.000 {method 'create_filled_contour' of 'matplotlib.QuadContourGenerator' objects}
#     16328    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#      1050    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         7    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/traitlets/config/configurable.py:38(__init__)
#         2    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:3299(set_xscale)
#         2    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/category.py:285(_is_dtype_compat)
#         2    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:834(_ticker)
#       213    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:622(set_antialiased)
#       125    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:310(set_facecolor)
#       136    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(diff)
#         2    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:3682(set_yscale)
#        45    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:913(process_value)
#      4916    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
#        80    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:2097(_process_unit_info)
#      2635    0.002    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2180(_check_in_list)
#        28    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(isclose)
#         2    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1503(_contour_args)
#        17    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1935(_get_label)
#       498    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1382(_to_unmasked_float_array)
#       354    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:2553(__init__)
#       845    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py:673(set_figure)
#      1794    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/abc.py:137(__instancecheck__)
#         2    0.000    0.000    0.002    0.001 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1274(_slice_take_blocks_ax0)
#       213    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:505(set_linestyle)
#         1    0.000    0.000    0.002    0.002 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4896(sort_values)
#        18    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:312(__init__)
#        18    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:697(union)
#       338    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py:747(_convert_units)
#       154    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py:397(lookup_by_type)
#       295    0.001    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:915(_set_artist_props)
#       160    0.000    0.000    0.002    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:2100(_process_single_axis)
#         1    0.000    0.000    0.002    0.002 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3732(_reindex_axes)
# ...
#         6    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:249(inferred_type)
#        12    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:383(inferred_type)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:999(dtype)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:232(__init__)
#        14    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:914(<dictcomp>)
#         9    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/multiarray.py:1043(copyto)
#         9    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:1336(_moveaxis_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:1786(isscalar)
#        12    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1689(_ravel_dispatcher)
#         7    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1800(_nonzero_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/function_base.py:21(_linspace_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/shape_base.py:1251(<genexpr>)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:1005(scaled)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:1637(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:2749(get_affine)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py:303(get_array)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:261(is_filled)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:412(_half_fill)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1338(get_alpha)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:817(get_position)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/gridspec.py:130(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:1798(_gci)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:4479(get_shared_x_axes)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py:1396(get_major_formatter)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1398(<lambda>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/common.py:192(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/sorting.py:129(is_int64_overflow_possible)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py:329(_na_ok_dtype)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:457(_constructor)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py:88(_ensure_type)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:609(<lambda>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:3661(array)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:5361(_ensure_has_len)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py:352(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:3656(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py:202(external_values)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1815(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1837(_shape_compat)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:508(_selected_obj)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:573(__getattr__)
#         8    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:402(group_index)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:528(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:563(is_in_axis)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:575(is_in_obj)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:641(_is_label_like)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py:788(juggle_axes)
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/enum.py:628(value)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/category.py:436(<lambda>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/multiarray.py:853(bincount)
#        17    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/multiarray.py:990(unravel_index)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:1191(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:1417(_cross_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1344(_resize_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2965(_cumprod_dispatcher)
#        11    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py:478(_unary_dispatcher)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py:2312(_norm_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:1274(_interp_dispatcher)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:4214(_delete_dispatcher)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:4636(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:462(_extend_lower)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/path.py:684(unit_circle)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:171(get_transforms)
#         8    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:680(get_facecolor)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:754(update_scalarmappable)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:892(get_paths)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py:318(get_path)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:371(set_offset_string)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/gridspec.py:119(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/_layoutbox.py:655(nonetree)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py:114(set_subplotspec)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:289(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:299(_setdefaults)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:4483(get_shared_y_axes)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/base.py:125(na_value)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/common.py:213(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py:166(_get_fill_value)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:399(_constructor)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:1625(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:1684(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2266(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2267(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py:210(start)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py:233(stop)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py:243(fill_value)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:419(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:3917(_needs_reindex_multi)
#         9    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py:100(groupings)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py:233(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:396(result_index)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/util.py:42(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/multiarray.py:929(ravel_multi_index)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py:655(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:1106(_roll_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:2283(_array_equal_dispatcher)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py:79(_atleast_2d_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py:137(_atleast_3d_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:436(_repeat_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2473(_ptp_dispatcher)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2838(_prod_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/type_check.py:207(_is_type_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/shape_base.py:1165(_tile_dispatcher)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:466(_extend_upper)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1673(<lambda>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:2035(frozen)
#        14    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:2075(inverted)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:1071(<listcomp>)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:376(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/base.py:405(ndim)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:1574(<genexpr>)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1691(is_all_dates)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py:256(step)
#         3    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py:1576(is_consolidated)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:390(codes)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/categorical.py:11(recode_for_groupby)
# 0

# %% [markdown]
# ## The following section was used to investigate the efficiency of the code

# %%
import cProfile, pstats, io



def profile(fnc):
    
    """A decorator that uses cProfile to profile a function"""
    
    def inner(*args, **kwargs):
        
        pr = cProfile.Profile()
        pr.enable()
        retval = fnc(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval

    return inner
